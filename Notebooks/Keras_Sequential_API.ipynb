# %% [markdown]
# # Keras Sequential API
#
# ## Classify images of clothing
#
# In this notebook, we will train a neural network to classify images of clothing from the Fashion MNIST dataset. The notebook is based on the public tutorial found here: https://www.tensorflow.org/tutorials/keras/classification

# %% [markdown]
# ##### Import the required modules

# %%
import tensorflow as tf
from tensorflow import keras
import matplotlib.pyplot as plt

# %% [markdown]
# ##### Download the Fashion MNIST Dataset
# We will use the `keras.datasets` package, which contains utility functions to download popular datasets with a few lines of code, without worrying about whether you are downloading from the correct source, or the correct version, etc.

# %%
(train_images, train_labels), (test_images, test_labels) = keras.datasets.fashion_mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step

# %% [markdown]
# The downloaded data will be stored on your disk in a hidden folder (e.g. `/Users/<username>/.keras/datasets/fashion-mnist` on MacOs.
#
# The variables `train_images` and `test_images` are numpy arrays of shape $(n_{images}, 28, 28)$, whereas `train_labels`, and `test_labels` are numpy arrays of size $(n_{images}, )$

# %%
print(train_images.shape)
print(train_labels.shape)
print(train_labels[:10])
# Out:
# (60000, 28, 28)
# (60000,)
# [9 0 0 3 0 2 7 2 5 5]

# %% [markdown]
# Each label is an integer in 0..9. Let us define the corresponding class names (they are not defined in the dataset)

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat',
               'Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %% [markdown]
# Finally, let us plot the first training image as an example.

# %%
plt.figure()
plt.imshow(train_images[1], cmap=plt.cm.binary)
plt.xlabel(class_names[train_labels[1]])
plt.grid(False)
plt.show()

# %% [markdown]
# ##### Let us build our first Keras model, with the Sequential API
#
# For this example, we will use a simple two-layer, fully-connected neural network.
#
# The network includes two types layer (sublcasses of `keras.layers.Layer`):
#
# - `Dense` layers (i.e. fully connected ones) take as mandatory parameters the number of output units. Optional parameters include the activation function, the presence of bias, etc.
# - `Flatten` layers are used to flatten a rank-N tensor (2 in this case) to a 1D array. Their input parameter is the shape of the input tensor.
#
# The `Flatten` layer is needed to feed the following `Dense` layers, which only accept (batches of) rank-1 tensors.

# %%
model = keras.Sequential([
    keras.layers.Flatten(input_shape=(28, 28)),
    # first layer
    keras.layers.Dense(128, activation='relu', name='first_dense'),
    # second layer
    keras.layers.Dense(10, activation='softmax', name='second_dense')
])

# %% [markdown]
# Let us show a summary of the model and plot it. Notice that the `Flatten` layer does not have trainable parameters. Also notice the `?`/`None` dimensions in the various layers. These mean that the layer can accept any value for that dimension (the batch size in this case).

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten_2 (Flatten)         (None, 784)               0
#
#  first_dense (Dense)         (None, 128)               100480
#
#  second_dense (Dense)        (None, 10)                1290
#
# =================================================================
# Total params: 101,770
# Trainable params: 101,770
# Non-trainable params: 0
# _________________________________________________________________

# %%
keras.utils.plot_model(model, 'tmp_new.png', show_shapes=True)
# Out:
# You must install pydot (`pip install pydot`) and install graphviz (see instructions at https://graphviz.gitlab.io/download/) for plot_model to work.

# %% [markdown]
# ##### Compile the model
#
# Let us now compile the model, specifying optimizer, loss function and metrics.

# %%
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
              metrics=['accuracy'])

# %% [markdown]
# ##### Train the model
#
# Let us now train the model. Remember that `np.ndarray` are automatically converted to TF tensors, so we don't need to do that explicitly when passing data to `fit()`

# %%
model.fit(train_images, train_labels, batch_size=32, epochs=100)
# Out:
# Epoch 1/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 3.6639 - accuracy: 0.6841
# Epoch 2/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6927 - accuracy: 0.7501
# Epoch 3/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.6006 - accuracy: 0.7934
# Epoch 4/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5498 - accuracy: 0.8074
# Epoch 5/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.5338 - accuracy: 0.8136
# Epoch 6/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5231 - accuracy: 0.8174
# Epoch 7/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5173 - accuracy: 0.8200
# Epoch 8/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5076 - accuracy: 0.8208
# Epoch 9/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5087 - accuracy: 0.8221
# Epoch 10/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4984 - accuracy: 0.8264
# Epoch 11/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.5032 - accuracy: 0.8235
# Epoch 12/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4919 - accuracy: 0.8277
# Epoch 13/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4973 - accuracy: 0.8278
# Epoch 14/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4877 - accuracy: 0.8301
# Epoch 15/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4898 - accuracy: 0.8288
# Epoch 16/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4939 - accuracy: 0.8292
# Epoch 17/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4802 - accuracy: 0.8327
# Epoch 18/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4861 - accuracy: 0.8292
# Epoch 19/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4782 - accuracy: 0.8343
# Epoch 20/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4764 - accuracy: 0.8321
# Epoch 21/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4711 - accuracy: 0.8345
# Epoch 22/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4800 - accuracy: 0.8315
# Epoch 23/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4746 - accuracy: 0.8338
# Epoch 24/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4709 - accuracy: 0.8353
# Epoch 25/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4733 - accuracy: 0.8318
# Epoch 26/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4801 - accuracy: 0.8325
# Epoch 27/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4727 - accuracy: 0.8343
# Epoch 28/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4767 - accuracy: 0.8335
# Epoch 29/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4622 - accuracy: 0.8363
# Epoch 30/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4624 - accuracy: 0.8365
# Epoch 31/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4700 - accuracy: 0.8337
# Epoch 32/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4601 - accuracy: 0.8372
# Epoch 33/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4705 - accuracy: 0.8368
# Epoch 34/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4582 - accuracy: 0.8393
# Epoch 35/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4675 - accuracy: 0.8356
# Epoch 36/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4749 - accuracy: 0.8343
# Epoch 37/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4624 - accuracy: 0.8379
# Epoch 38/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4890 - accuracy: 0.8327
# Epoch 39/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4657 - accuracy: 0.8350
# Epoch 40/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4643 - accuracy: 0.8373
# Epoch 41/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4640 - accuracy: 0.8334
# Epoch 42/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4579 - accuracy: 0.8377
# Epoch 43/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4574 - accuracy: 0.8394
# Epoch 44/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4622 - accuracy: 0.8375
# Epoch 45/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4657 - accuracy: 0.8372
# Epoch 46/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4499 - accuracy: 0.8399
# Epoch 47/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4651 - accuracy: 0.8352
# Epoch 48/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4652 - accuracy: 0.8364
# Epoch 49/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4658 - accuracy: 0.8367
# Epoch 50/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4600 - accuracy: 0.8368
# Epoch 51/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4619 - accuracy: 0.8369
# Epoch 52/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4551 - accuracy: 0.8375
# Epoch 53/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4558 - accuracy: 0.8409
# Epoch 54/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4581 - accuracy: 0.8406
# Epoch 55/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4618 - accuracy: 0.8377
# Epoch 56/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4597 - accuracy: 0.8376
# Epoch 57/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4493 - accuracy: 0.8419
# Epoch 58/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4619 - accuracy: 0.8411
# Epoch 59/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4530 - accuracy: 0.8398
# Epoch 60/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4542 - accuracy: 0.8396
# Epoch 61/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4505 - accuracy: 0.8413
# Epoch 62/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4494 - accuracy: 0.8390
# Epoch 63/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4554 - accuracy: 0.8404
# Epoch 64/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4482 - accuracy: 0.8415
# Epoch 65/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4584 - accuracy: 0.8385
# Epoch 66/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4509 - accuracy: 0.8410
# Epoch 67/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4437 - accuracy: 0.8417
# Epoch 68/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4602 - accuracy: 0.8421
# Epoch 69/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4679 - accuracy: 0.8357
# Epoch 70/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4555 - accuracy: 0.8385
# Epoch 71/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4660 - accuracy: 0.8380
# Epoch 72/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4538 - accuracy: 0.8405
# Epoch 73/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4449 - accuracy: 0.8410
# Epoch 74/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4570 - accuracy: 0.8400
# Epoch 75/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4466 - accuracy: 0.8426
# Epoch 76/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4508 - accuracy: 0.8426
# Epoch 77/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4529 - accuracy: 0.8408
# Epoch 78/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4538 - accuracy: 0.8415
# Epoch 79/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4401 - accuracy: 0.8441
# Epoch 80/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4471 - accuracy: 0.8389
# Epoch 81/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4633 - accuracy: 0.8379
# Epoch 82/100
# 1875/1875 [==============================] - 5s 3ms/step - loss: 0.4457 - accuracy: 0.8416
# Epoch 83/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4520 - accuracy: 0.8391
# Epoch 84/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4721 - accuracy: 0.8398
# Epoch 85/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4530 - accuracy: 0.8389
# Epoch 86/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4459 - accuracy: 0.8407
# Epoch 87/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4508 - accuracy: 0.8407
# Epoch 88/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4445 - accuracy: 0.8405
# Epoch 89/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4489 - accuracy: 0.8405
# Epoch 90/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4426 - accuracy: 0.8423
# Epoch 91/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4669 - accuracy: 0.8356
# Epoch 92/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4597 - accuracy: 0.8394
# Epoch 93/100
# 1875/1875 [==============================] - 4s 2ms/step - loss: 0.4415 - accuracy: 0.8441
# Epoch 94/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4600 - accuracy: 0.8400
# Epoch 95/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4479 - accuracy: 0.8407
# Epoch 96/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4590 - accuracy: 0.8395
# Epoch 97/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4592 - accuracy: 0.8403
# Epoch 98/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4510 - accuracy: 0.8413
# Epoch 99/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4443 - accuracy: 0.8429
# Epoch 100/100
# 1875/1875 [==============================] - 5s 2ms/step - loss: 0.4611 - accuracy: 0.8375

# %% [markdown]
# ##### Evaluate on unseen data
#
# Let us test the model on unseen data using the `evaluate()` method.

# %%
test_loss, test_acc = model.evaluate(test_images,  test_labels, verbose=2)
print('\nTest accuracy:', test_acc)
# Out:
# 313/313 - 0s - loss: 0.7921 - accuracy: 0.8141 - 470ms/epoch - 2ms/step
#
# Test accuracy: 0.8141000270843506

# %% [markdown]
# ##### Perform a prediction on a single image
#
# Let us run a prediction on one image and see the result.

# %%
idx = 7

pred = model.predict(test_images[idx].reshape(1, 28, 28))
# we take only the index with highest probability through argmax
pred_lidx = tf.argmax(pred[0])
pred_label = class_names[pred_lidx]

print("Predicted label: {} ({})".format(pred_lidx, pred_label))
print("Real label: {} ({})".format(test_labels[idx], class_names[test_labels[idx]]))

plt.figure()
plt.imshow(test_images[idx], cmap=plt.cm.binary)
plt.grid(False)
plt.figure()
plt.bar(range(len(class_names)), pred[0], tick_label=class_names)
plt.xticks(rotation=45)
plt.show()
# Out:
# 1/1 [==============================] - 0s 43ms/step
# Predicted label: 6 (Shirt)
# Real label: 6 (Shirt)

# %% [markdown]
# <a style='text-decoration:none;line-height:16px;display:flex;color:#5B5B62;padding:10px;justify-content:end;' href='https://deepnote.com?utm_source=created-in-deepnote-cell&projectId=7817b2ad-42a3-441f-8072-b020be286d3c' target="_blank">
# <img alt='Created in deepnote.com' style='display:inline;max-height:16px;margin:0px;margin-right:7.5px;' src='data:image/svg+xml;base64,...' > </img>
# Created in <span style='font-weight:600;margin-left:4px;'>Deepnote</span></a>
